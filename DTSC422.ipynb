# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p data/benchmark
# !cp "/content/drive/MyDrive/odia-nli/indicxnli-train.parquet"      data/benchmark/
# !cp "/content/drive/MyDrive/odia-nli/indicxnli-validation.parquet" data/benchmark/
# !cp "/content/drive/MyDrive/odia-nli/indicxnli-test.parquet"       data/benchmark/
# !ls -la data/benchmark/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# total 71928
# drwxr-xr-x 2 root root     4096 Sep 22 13:20 .
# drwxr-xr-x 3 root root     4096 Sep 22 13:19 ..
# -rw------- 1 root root   486108 Sep 22 13:37 indicxnli-test.parquet
# -rw------- 1 root root 72912369 Sep 22 13:37 indicxnli-train.parquet
# -rw------- 1 root root   241753 Sep 22 13:37 indicxnli-validation.parquet

# %%
# !pip install transformers datasets accelerate scikit-learn pandas pyarrow -q

# %%
import torch
print(torch.cuda.is_available(), torch.cuda.get_device_name(0))
# Out:
# True Tesla T4

# %%
# %cd /content/drive/MyDrive/odia-nli !Python train_benchmark.py --train_file indicxnli-train.parquet --val_file indicxnli-validation.parquet --test_file indicxnli-test.parquet --subset_train 2000 --num_train_epochs
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/odia-nli !train_benchmark.py --train_file indicxnli-train.parquet --val_file indicxnli-validation.parquet --test_file indicxnli-test.parquet --subset_train 2000 --num_train_epochs'
# /content

# %%
# %cd /content/drive/MyDrive/odia-nli
# Out:
# /content/drive/MyDrive/odia-nli

# %%
# !python train_benchmark.py --train_file indicxnli-train.parquet --val_file indicxnli-validation.parquet --test_file indicxnli-test.parquet --subset_train 2000 --num_train_epochs 1
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 392702
#     })
#     validation: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 2490
#     })
#     test: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 5010
#     })
# })
# ...
# config.json: 100% 639/639 [00:00<00:00, 2.73MB/s]
# tokenizer_config.json: 100% 51.0/51.0 [00:00<00:00, 274kB/s]
#
# tokenizer.json: downloading bytes:   0% 0.00/7.75M [00:00<?, ?B/s]
# tokenizer.json: downloading bytes: 100% 3.64M/3.64M [00:01<00:00, 2.68MB/s,  352kB/s  ]
# tokenizer.json: reconstructing file: 100% 7.75M/7.75M [00:01<00:00, 5.71MB/s,  749kB/s  ]
# special_tokens_map.json: 100% 125/125 [00:00<00:00, 537kB/s]
# Map: 100% 2000/2000 [00:00<00:00, 8886.70 examples/s]
# Map: 100% 2490/2490 [00:00<00:00, 10934.32 examples/s]
# Map: 100% 5010/5010 [00:00<00:00, 7192.16 examples/s]
#
# ...

# %%
# %cd /content/drive/MyDrive/odia-nli
# Out:
# /content/drive/MyDrive/odia-nli

# %%
# !python train_benchmark.py --train_file indicxnli-train.parquet --val_file indicxnli-validation.parquet --test_file indicxnli-test.parquet --subset_train 2000 --num_train_epochs 1
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 392702
#     })
#     validation: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 2490
#     })
#     test: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 5010
#     })
# })
# ...
# Map: 100% 2000/2000 [00:00<00:00, 4827.38 examples/s]
# Map: 100% 2490/2490 [00:00<00:00, 11460.75 examples/s]
# Map: 100% 5010/5010 [00:00<00:00, 11805.13 examples/s]
# Loading weights: 100% 199/199 [00:00<00:00, 25073.34it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: ai4bharat/IndicBERTv2-MLM-only
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# ...

# %%
import transformers
print(transformers.__version__)
# Out:
# 5.17.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -U transformers accelerate datasets scikit-learn pandas pyarrow -q

# %%
import transformers
print(transformers.__version__)
# Out:
# 5.17.0

# %%
# %cd /content/drive/MyDrive/odia-nli
# Out:
# /content/drive/MyDrive/odia-nli

# %%
# !python train_benchmark.py --train_file indicxnli-train.parquet --val_file indicxnli-validation.parquet --test_file indicxnli-test.parquet --subset_train 2000 --num_train_epochs 1
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 392702
#     })
#     validation: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 2490
#     })
#     test: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 5010
#     })
# })
# ...
# Map: 100% 2000/2000 [00:00<00:00, 3613.65 examples/s]
# Map: 100% 2490/2490 [00:00<00:00, 11922.15 examples/s]
# Map: 100% 5010/5010 [00:00<00:00, 11780.52 examples/s]
# Loading weights: 100% 199/199 [00:00<00:00, 22659.60it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: ai4bharat/IndicBERTv2-MLM-only
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# ...

# %%
# !python train_benchmark.py --train_file indicxnli-train.parquet --val_file indicxnli-validation.parquet --test_file indicxnli-test.parquet --subset_train 2000 --num_train_epochs 1
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 392702
#     })
#     validation: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 2490
#     })
#     test: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 5010
#     })
# })
# ...
# Map: 100% 2000/2000 [00:00<00:00, 4519.86 examples/s]
# Map: 100% 2490/2490 [00:00<00:00, 11678.76 examples/s]
# Map: 100% 5010/5010 [00:00<00:00, 11077.79 examples/s]
# Loading weights: 100% 199/199 [00:00<00:00, 24291.10it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: ai4bharat/IndicBERTv2-MLM-only
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# ...

# %%
# !python train_benchmark.py --train_file indicxnli-train.parquet --val_file indicxnli-validation.parquet --test_file indicxnli-test.parquet --output_dir /content/drive/MyDrive/odia-nli/indicbertv2-odia-nli
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 392702
#     })
#     validation: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 2490
#     })
#     test: Dataset({
#         features: ['premise', 'hypothesis', 'label'],
#         num_rows: 5010
#     })
# })
# ...
# Map: 100% 392702/392702 [00:42<00:00, 9161.09 examples/s]
# Map: 100% 2490/2490 [00:00<00:00, 10961.86 examples/s]
# Map: 100% 5010/5010 [00:00<00:00, 10710.38 examples/s]
# Loading weights: 100% 199/199 [00:00<00:00, 18949.02it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: ai4bharat/IndicBERTv2-MLM-only
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# ...
